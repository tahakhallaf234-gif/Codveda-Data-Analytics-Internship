# %% [markdown]
# # 🧹 Iris Data Cleaning & Preprocessing
#
# ## Codveda Data Analytics Internship
#
# ### Author
# Taha Ahmed Khallaf
#
# ---
#
# ## Objective
#
# The goal of this project is to clean and preprocess the Iris dataset before performing data analysis.

# %% [markdown]
# ## Import Libraries

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ## Load Dataset

# %%
df = pd.read_csv("/content/1) iris.csv")

# %% [markdown]
# ## Display Dataset

# %%
df.head(3)
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa

# %% [markdown]
# ## Dataset Information

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 5 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   sepal_length  150 non-null    float64
#  1   sepal_width   150 non-null    float64
#  2   petal_length  150 non-null    float64
#  3   petal_width   150 non-null    float64
#  4   species       150 non-null    object
# dtypes: float64(4), object(1)
# memory usage: 6.0+ KB

# %% [markdown]
# ## Dataset Shape

# %%
print("Dataset Shape:", df.shape)
# Out:
# Dataset Shape: (150, 5)

# %% [markdown]
# ## Check Missing Values

# %%
if df.isnull().sum().sum() == 0:
    print("No missing values found.")
# Out:
# No missing values found.

# %% [markdown]
# ## Check Duplicate Rows

# %%
print(f"Number of duplicate rows: {df.duplicated().sum()}")
# Out:
# Number of duplicate rows: 3

# %% [markdown]
# ## Remove Duplicate Rows

# %%
df.drop_duplicates(inplace=True)
print(f"New shape of DataFrame after removing duplicates: {df.shape}")
# Out:
# New shape of DataFrame after removing duplicates: (147, 5)

# %% [markdown]
# ## Final Shape

# %%
print("Final Shape:", df.shape)
# Out:
# Final Shape: (150, 5)

# %% [markdown]
# ## Check Data Types

# %%
print(df.dtypes)
# Out:
# sepal_length    float64
# sepal_width     float64
# petal_length    float64
# petal_width     float64
# species          object
# dtype: object

# %% [markdown]
# ## Conclusion
#
# - Dataset loaded successfully.
# - No missing values found.
# - Duplicate rows removed.
# - Dataset is ready for Exploratory Data Analysis.
